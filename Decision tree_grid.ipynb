# %%
import pandas as pd
import numpy as np
import matplotlib as matlab

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#sklearn library used to split train and test model
from sklearn.model_selection import train_test_split
#Then call train_test_split function it is parameterised function
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(criterion="mae",splitter="random",max_features="sqrt")
regressor=regressor.fit(X_train,Y_train)

# %%
#this library for graph purpose
import matplotlib.pyplot as plt
from sklearn import tree
tree.plot_tree(regressor)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={"criterion":['mse','mae','friedman_mse'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#fitting the model for grid search
grid.fit(X_train,Y_train)
#regressor=SVR(kernel="precomputed",C=10)
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\spavi\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:   18.2s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print (re)
grid_predictions=grid.predict(X_test)
#print classification report
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}: 0.7574489769063929

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005208      0.007365         0.010414        0.007364
# 1        0.005207      0.007364         0.000000        0.000000
# 2        0.002658      0.003759         0.001662        0.002351
# 3        0.005207      0.007364         0.005207        0.007364
# 4        0.000299      0.000423         0.010415        0.007364
# 5        0.005207      0.007364         0.005208        0.007365
# 6        0.045442      0.012912         0.005207        0.007364
# 7        0.024842      0.006681         0.010414        0.014727
# 8        0.034678      0.008885         0.002328        0.003292
# 9        0.028366      0.006659         0.004987        0.001629
# 10       0.027260      0.001696         0.009642        0.006581
# 11       0.016301      0.006278         0.008170        0.008283
# 12       0.002992      0.004231         0.011745        0.005484
# 13       0.011528      0.003149         0.005351        0.004525
# 14       0.010415      0.007364         0.005207        0.007364
# 15       0.000000      0.000000         0.005208        0.007365
# 16       0.005208      0.007365         0.005208        0.007365
# 17       0.005208      0.007365         0.005207        0.007364
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.569911
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.642445
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.691870
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.636364
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.635904
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.631918
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.642071
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.637847
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.493213
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.552750
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.667063
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.611177
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.545480
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.554794
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.446922
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.593673
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.649345
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.515618
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.690563           0.627912         0.629462        0.049268
# 1            0.643136           0.671432         0.652337        0.013505
# 2            0.669612           0.630259         0.663914        0.025474
# 3            0.641200           0.618449         0.632005        0.009786
# 4            0.636446           0.678859         0.650403        0.020123
# 5            0.593984           0.616117         0.614006        0.015558
# 6            0.636227           0.698768         0.659022        0.028206
# 7            0.640342           0.614698         0.630962        0.011545
# 8            0.688216           0.661004         0.614145        0.086230
# 9            0.612370           0.567311         0.577477        0.025379
# 10           0.386233           0.711457         0.588251        0.143993
# 11           0.555040           0.580884         0.582367        0.022942
# 12           0.687117           0.636007         0.622868        0.058565
# 13           0.701535           0.721576         0.659302        0.074349
# 14           0.729493           0.678085         0.618166        0.122894
# 15           0.645446           0.586114         0.608411        0.026369
# 16           0.733904           0.629513         0.670921        0.045266
# 17           0.657638           0.595836         0.589697        0.058142
#
#     rank_test_score
# 0                 9
# 1                 5
# 2                 2
# 3                 7
# 4                 6
# 5                13
# 6                 4
# 7                 8
# 8                12
# 9                18
# 10               16
# 11               17
# 12               10
# 13                3
# 14               11
# 15               14
# 16                1
# 17               15

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:45
# BMI:67
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,
smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[63770.42801]
